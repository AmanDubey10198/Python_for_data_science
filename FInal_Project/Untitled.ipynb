# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataset1 = pd.read_csv('rainfall_in_india_1901-2015.csv')
dataset2 = pd.read_csv('district wise rainfall normal.csv')

# %%
dataset1.shape
# Out:
# (4116, 19)

# %%
dataset2.shape
# Out:
# (641, 19)

# %%
from scipy import misc

# %%
map = misc.imread('india.png')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
type(map)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize = (15,15))
plt.imshow(map)

# %%
map[0:100,150:200] = 200
plt.figure(figsize = (15,15))
plt.imshow(map)
