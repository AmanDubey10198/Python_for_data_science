# %% [markdown]
# # Data Visualization

# %%
import pandas as pd

# %%
ratings = pd.read_csv("./movielens/ratings.csv")

# %%
ratings.hist(column = 'rating', figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B677F11128>]],
#       dtype=object)

# %%
ratings.boxplot(column = 'rating', figsize =(15,20))
