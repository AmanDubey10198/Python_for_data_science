# %% [markdown]
# # Frequent Data Operations

# %% [markdown]
# ## Slicing Out Column

# %%
import pandas as pd

# %%
tags = pd.read_csv("./movielens/tags.csv")

# %%
tags['tag'].head()
# Out:
# 0    sandra 'boring' bullock
# 1                    dentist
# 2                   Cambodia
# 3                    Russian
# 4                forgettable
# Name: tag, dtype: object

# %% [markdown]
# ## Filter Out Rows

# %%
tags.head()
# Out:
#    userId  movieId                      tag   timestamp
# 0      15      339  sandra 'boring' bullock  1138537770
# 1      15     1955                  dentist  1193435061
# 2      15     7478                 Cambodia  1170560997
# 3      15    32892                  Russian  1170626366
# 4      15    34162              forgettable  1141391765

# %%
tags[tags['userId']>15].head()
# Out:
#     userId  movieId           tag   timestamp
# 11      23      150    Ron Howard  1148672905
# 12      68     2174         music  1249808064
# 13      68     2174         weird  1249808102
# 14      68     8623  Steve Martin  1249808497
# 15      73   107999        action  1430799184

# %% [markdown]
# ## Insert New Column

# %%
tags['extra'] = tags['movieId'] + 100

# %%
tags.head()
# Out:
#    userId  movieId                      tag   timestamp  extra
# 0      15      339  sandra 'boring' bullock  1138537770    439
# 1      15     1955                  dentist  1193435061   2055
# 2      15     7478                 Cambodia  1170560997   7578
# 3      15    32892                  Russian  1170626366  32992
# 4      15    34162              forgettable  1141391765  34262

# %% [markdown]
# ## Add a New Row

# %%
tags.loc[2] = [14,"Baba ji ka thullu",132324223,456]

# %%
tags.head()
# Out:
#    userId            movieId                      tag  extra
# 0      15                339  sandra 'boring' bullock    439
# 1      15               1955                  dentist   2055
# 2      14  Baba ji ka thullu                132324223    456
# 3      15              32892                  Russian  32992
# 4      15              34162              forgettable  34262

# %% [markdown]
# ## Delete a Row

# %%
tags.drop(tags.index[(1)]).head()
# Out:
#    userId  movieId                      tag   timestamp  extra
# 0      15      339  sandra 'boring' bullock  1138537770    439
# 2      15     7478                 Cambodia  1170560997   7578
# 3      15    32892                  Russian  1170626366  32992
# 4      15    34162              forgettable  1141391765  34262
# 5      15    35957                    short  1141391873  36057

# %% [markdown]
# ## Delete a Columns

# %%
del tags['timestamp']

# %%
tags.head()
# Out:
#    userId  movieId                      tag  extra
# 0      15      339  sandra 'boring' bullock    439
# 1      15     1955                  dentist   2055
# 2      15     7478                 Cambodia   7578
# 3      15    32892                  Russian  32992
# 4      15    34162              forgettable  34262

# %% [markdown]
# ## Group By and Aggregate

# %%
ratings = pd.read_csv("./movielens/ratings.csv")

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings[['movieId','rating']].groupby('movieId').mean().head()
# Out:
#            rating
# movieId
# 1        3.872470
# 2        3.401869
# 3        3.161017
# 4        2.384615
# 5        3.267857

# %% [markdown]
# **http://pandas.pydata.org/pandas-docs/stable/api.html**

# %% [markdown]
# ## Slicing out column

# %%
tags['tag'].head()
# Out:
# 0    sandra 'boring' bullock
# 1                    dentist
# 2                   Cambodia
# 3                    Russian
# 4                forgettable
# Name: tag, dtype: object

# %%
movies = pd.read_csv("./movielens/movies.csv")

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#         userId  movieId  rating   timestamp
# 99994      671     5952     5.0  1063502716
# 99995      671     5989     4.0  1064890625
# 99996      671     5991     4.5  1064245387
# 99997      671     5995     4.0  1066793014
# 99998      671     6212     2.5  1065149436
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724

# %%
tc = tags['tag'].value_counts()
tc[:10]
# Out:
# getdvd       33
# Ei muista    29
# tivo         26
# toplist07    26
# toplist12    20
# toplist11    20
# tcm          20
# toplist15    19
# toplist08    19
# toplist09    18
# Name: tag, dtype: int64

# %%
tc[:10].plot(kind = 'bar', figsize = (15,10))

# %% [markdown]
# ## Filters for Selecting Rows

# %%
is_highly_rated = ratings['rating'] >= 4.0
ratings[is_highly_rated][20: 50]
# Out:
#      userId  movieId  rating   timestamp
# 56        2      350     4.0   835355697
# 68        2      454     4.0   835355604
# 70        2      468     4.0   835355790
# 72        2      480     4.0   835355643
# 75        2      500     4.0   835355731
# 76        2      508     4.0   835355860
# 77        2      509     4.0   835355719
# 78        2      515     4.0   835355817
# 79        2      527     4.0   835355731
# 80        2      537     4.0   835356199
# 83        2      551     5.0   835355767
# 85        2      585     5.0   835355817
# 89        2      589     5.0   835355697
# 90        2      590     5.0   835355395
# 91        2      592     5.0   835355395
# 94        2      661     4.0   835356141
# 95        2      720     4.0   835355978
# 97        3      110     4.0  1298922049
# 100       3      296     4.5  1298862418
# 101       3      318     5.0  1298862121
# 103       3      356     5.0  1298862167
# 111       3      778     4.0  1298863157
# ...

# %%
is_animation = movies['genres'].str.contains('Animation')
movies[is_animation][:10]
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 46        48                           Pocahontas (1995)
# 211      239                       Goofy Movie, A (1995)
# 216      244                     Gumby: The Movie (1995)
# 279      313                   Swan Princess, The (1994)
# 328      364                       Lion King, The (1994)
# 354      392  Secret Adventures of Tom Thumb, The (1993)
# 494      551      Nightmare Before Christmas, The (1993)
# 500      558                      Pagemaster, The (1994)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 46          Animation|Children|Drama|Musical|Romance
# 211                Animation|Children|Comedy|Romance
# 216                               Animation|Children
# ...

# %% [markdown]
# ## Group By and Aggregate

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5        1101
# 1.0        3326
# 1.5        1687
# 2.0        7271
# 2.5        4449
# 3.0       20064
# 3.5       10538
# 4.0       28750
# 4.5        7723
# 5.0       15095

# %%
average_ratings = ratings[['movieId','rating']].groupby('rating').mean()
average_ratings.tail()
# Out:
#              movieId
# rating
# 3.0      8929.347089
# 3.5     19679.382426
# 4.0     10967.919270
# 4.5     19058.786611
# 5.0      9010.328652
